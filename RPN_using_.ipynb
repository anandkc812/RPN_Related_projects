# %%
##https://fairyonice.github.io/Learn-about-Fully-Convolutional-Networks-for-semantic-segmentation.html

# %%
from google.colab import drive


drive.mount('/content/gdrive')
filename = '/content/gdrive/My Drive/data/dataset1.zip'

! cp  gdrive/My*Drive/data/dataset1.zip .


# !unzip -q dataset1.zip
# !ls dataset1
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive
# annotations_prepped_test   images_prepped_test
# annotations_prepped_train  images_prepped_train

# %% [markdown]
# Visualize a single segmentation image
# In this data, there are 12 segmentation classes and the image is from a driving car.

# %%
import cv2, os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
## seaborn has white grid by default so I will get rid of this.
sns.set_style("whitegrid", {'axes.grid' : False})

dir_data = "dataset1/"
dir_seg = dir_data + "/annotations_prepped_train/"
dir_img = dir_data + "/images_prepped_train/"

ldseg = np.array(os.listdir(dir_seg))
## pick the first image file
fnm = ldseg[0]
print(fnm)

## read in the original image and segmentation labels
seg = cv2.imread(dir_seg + fnm ) # (360, 480, 3)
img_is = cv2.imread(dir_img + fnm )
print("seg.shape={}, img_is.shape={}".format(seg.shape,img_is.shape))

## Check the number of labels
mi, ma = np.min(seg), np.max(seg)
n_classes = ma - mi + 1
print("minimum seg = {}, maximum seg = {}, Total number of segmentation classes = {}".format(mi,ma, n_classes))

fig = plt.figure(figsize=(5,5))
ax = fig.add_subplot(1,1,1)
ax.imshow(img_is)
ax.set_title("original image")
plt.show()

fig = plt.figure(figsize=(15,10))
for k in range(mi,ma+1):
    ax = fig.add_subplot(3,n_classes/3,k+1)
    ax.imshow((seg == k)*1.0)
    ax.set_title("label = {}".format(k))


plt.show()
# Out:
# 0001TP_008520.png
# seg.shape=(360, 480, 3), img_is.shape=(360, 480, 3)
# minimum seg = 0, maximum seg = 11, Total number of segmentation classes = 12

# %% [markdown]
# Data preprocessing: Resize image
# To simplify the problem, Lets reshape all the images to the same size: (224,224).

# %%
import random
def give_color_to_seg_img(seg,n_classes):
    '''
    seg : (input_width,input_height,3)
    '''
    
    if len(seg.shape)==3:
        seg = seg[:,:,0]
    seg_img = np.zeros( (seg.shape[0],seg.shape[1],3) ).astype('float')
    colors = sns.color_palette("hls", n_classes)
    
    for c in range(n_classes):
        segc = (seg == c)
        seg_img[:,:,0] += (segc*( colors[c][0] ))
        seg_img[:,:,1] += (segc*( colors[c][1] ))
        seg_img[:,:,2] += (segc*( colors[c][2] ))

    return(seg_img)

input_height , input_width = 224 , 224
output_height , output_width = 224 , 224


ldseg = np.array(os.listdir(dir_seg))
for fnm in ldseg[np.random.choice(len(ldseg),3,replace=False)]:
    fnm = fnm.split(".")[0]
    seg = cv2.imread(dir_seg + fnm + ".png") # (360, 480, 3)
    img_is = cv2.imread(dir_img + fnm + ".png")
    seg_img = give_color_to_seg_img(seg,n_classes)

    fig = plt.figure(figsize=(20,40))
    ax = fig.add_subplot(1,4,1)
    ax.imshow(seg_img)
    
    ax = fig.add_subplot(1,4,2)
    ax.imshow(img_is/255.0)
    ax.set_title("original image {}".format(img_is.shape[:2]))
    
    ax = fig.add_subplot(1,4,3)
    ax.imshow(cv2.resize(seg_img,(input_height , input_width)))
    
    ax = fig.add_subplot(1,4,4)
    ax.imshow(cv2.resize(img_is,(output_height , output_width))/255.0)
    ax.set_title("resized to {}".format((output_height , output_width)))
    plt.show()

# %%
def getImageArr( path , width , height ):
        img = cv2.imread(path, 1)
        img = np.float32(cv2.resize(img, ( width , height ))) / 127.5 - 1
        return img

def getSegmentationArr( path , nClasses ,  width , height  ):

    seg_labels = np.zeros((  height , width  , nClasses ))
    img = cv2.imread(path, 1)
    img = cv2.resize(img, ( width , height ))
    img = img[:, : , 0]

    for c in range(nClasses):
        seg_labels[: , : , c ] = (img == c ).astype(int)
    ##seg_labels = np.reshape(seg_labels, ( width*height,nClasses  ))
    return seg_labels




images = os.listdir(dir_img)
images.sort()
segmentations  = os.listdir(dir_seg)
segmentations.sort()
    
X = []
Y = []
for im , seg in zip(images,segmentations) :
    X.append( getImageArr(dir_img + im , input_width , input_height )  )
    Y.append( getSegmentationArr( dir_seg + seg , n_classes , output_width , output_height )  )

X, Y = np.array(X) , np.array(Y)
print(X.shape,Y.shape)
# Out:
# (367, 224, 224, 3) (367, 224, 224, 12)

# %%
## Import usual libraries
import tensorflow as tf
from keras.backend.tensorflow_backend import set_session
import keras, sys, time, warnings
from keras.models import *
from keras.layers import *
import pandas as pd 
warnings.filterwarnings("ignore")

#os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID" 
#config = tf.ConfigProto()
#config.gpu_options.per_process_gpu_memory_fraction = 0.95
#config.gpu_options.visible_device_list = "2" 
#set_session(tf.Session(config=config))   

print("python {}".format(sys.version))
print("keras version {}".format(keras.__version__)); del keras
print("tensorflow version {}".format(tf.__version__))
# Out:
# python 3.6.8 (default, Jan 14 2019, 11:02:34)
# [GCC 8.0.1 20180414 (experimental) [trunk revision 259383]]
# keras version 2.2.4
# tensorflow version 1.14.0

# %%
VGG_Weights_path = "/content/gdrive/My Drive/data/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5"

def FCN8( nClasses ,  input_height=224, input_width=224):
    ## input_height and width must be devisible by 32 because maxpooling with filter size = (2,2) is operated 5 times,
    ## which makes the input_height and width 2^5 = 32 times smaller
    assert input_height%32 == 0
    assert input_width%32 == 0
    IMAGE_ORDERING =  "channels_last" 

    img_input = Input(shape=(input_height,input_width, 3)) ## Assume 224,224,3
    
    ## Block 1
    x = Conv2D(64, (3, 3), activation='relu', padding='same', name='block1_conv1', data_format=IMAGE_ORDERING )(img_input)
    x = Conv2D(64, (3, 3), activation='relu', padding='same', name='block1_conv2', data_format=IMAGE_ORDERING )(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), name='block1_pool', data_format=IMAGE_ORDERING )(x)
    f1 = x
    
    # Block 2
    x = Conv2D(128, (3, 3), activation='relu', padding='same', name='block2_conv1', data_format=IMAGE_ORDERING )(x)
    x = Conv2D(128, (3, 3), activation='relu', padding='same', name='block2_conv2', data_format=IMAGE_ORDERING )(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), name='block2_pool', data_format=IMAGE_ORDERING )(x)
    f2 = x

    # Block 3
    x = Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv1', data_format=IMAGE_ORDERING )(x)
    x = Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv2', data_format=IMAGE_ORDERING )(x)
    x = Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv3', data_format=IMAGE_ORDERING )(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), name='block3_pool', data_format=IMAGE_ORDERING )(x)
    pool3 = x

    # Block 4
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv1', data_format=IMAGE_ORDERING )(x)
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv2', data_format=IMAGE_ORDERING )(x)
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv3', data_format=IMAGE_ORDERING )(x)
    pool4 = MaxPooling2D((2, 2), strides=(2, 2), name='block4_pool', data_format=IMAGE_ORDERING )(x)## (None, 14, 14, 512) 

    # Block 5
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block5_conv1', data_format=IMAGE_ORDERING )(pool4)
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block5_conv2', data_format=IMAGE_ORDERING )(x)
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block5_conv3', data_format=IMAGE_ORDERING )(x)
    pool5 = MaxPooling2D((2, 2), strides=(2, 2), name='block5_pool', data_format=IMAGE_ORDERING )(x)## (None, 7, 7, 512)

    #x = Flatten(name='flatten')(x)
    #x = Dense(4096, activation='relu', name='fc1')(x)
    # <--> o = ( Conv2D( 4096 , ( 7 , 7 ) , activation='relu' , padding='same', data_format=IMAGE_ORDERING))(o)
    # assuming that the input_height = input_width = 224 as in VGG data
    
    #x = Dense(4096, activation='relu', name='fc2')(x)
    # <--> o = ( Conv2D( 4096 , ( 1 , 1 ) , activation='relu' , padding='same', data_format=IMAGE_ORDERING))(o)   
    # assuming that the input_height = input_width = 224 as in VGG data
    
    #x = Dense(1000 , activation='softmax', name='predictions')(x)
    # <--> o = ( Conv2D( nClasses ,  ( 1 , 1 ) ,kernel_initializer='he_normal' , data_format=IMAGE_ORDERING))(o)
    # assuming that the input_height = input_width = 224 as in VGG data
    
    
    vgg  = Model(  img_input , pool5  )
    vgg.load_weights(VGG_Weights_path) ## loading VGG weights for the encoder parts of FCN8
    
    n = 4096
    o = ( Conv2D( n , ( 7 , 7 ) , activation='relu' , padding='same', name="conv6", data_format=IMAGE_ORDERING))(pool5)
    conv7 = ( Conv2D( n , ( 1 , 1 ) , activation='relu' , padding='same', name="conv7", data_format=IMAGE_ORDERING))(o)
    
    
    ## 4 times upsamping for pool4 layer
    conv7_4 = Conv2DTranspose( nClasses , kernel_size=(4,4) ,  strides=(4,4) , use_bias=False, data_format=IMAGE_ORDERING )(conv7)
    ## (None, 224, 224, 10)
    ## 2 times upsampling for pool411
    pool411 = ( Conv2D( nClasses , ( 1 , 1 ) , activation='relu' , padding='same', name="pool4_11", data_format=IMAGE_ORDERING))(pool4)
    pool411_2 = (Conv2DTranspose( nClasses , kernel_size=(2,2) ,  strides=(2,2) , use_bias=False, data_format=IMAGE_ORDERING ))(pool411)
    
    pool311 = ( Conv2D( nClasses , ( 1 , 1 ) , activation='relu' , padding='same', name="pool3_11", data_format=IMAGE_ORDERING))(pool3)
        
    o = Add(name="add")([pool411_2, pool311, conv7_4 ])
    o = Conv2DTranspose( nClasses , kernel_size=(8,8) ,  strides=(8,8) , use_bias=False, data_format=IMAGE_ORDERING )(o)
    o = (Activation('softmax'))(o)
    
    model = Model(img_input, o)

    return model

model = FCN8(nClasses     = n_classes,  
             input_height = 224, 
             input_width  = 224)
model.summary()
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0726 11:16:43.814590 139969783146368 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0726 11:16:43.816427 139969783146368 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0726 11:16:43.821091 139969783146368 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0726 11:16:43.861000 139969783146368 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# W0726 11:16:46.674435 139969783146368 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# W0726 11:16:46.675706 139969783146368 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 224, 224, 64) 1792        input_1[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, 224, 224, 64) 36928       block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_pool (MaxPooling2D)      (None, 112, 112, 64) 0           block1_conv2[0][0]
# __________________________________________________________________________________________________
# block2_conv1 (Conv2D)           (None, 112, 112, 128 73856       block1_pool[0][0]
# __________________________________________________________________________________________________
# block2_conv2 (Conv2D)           (None, 112, 112, 128 147584      block2_conv1[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling2D)      (None, 56, 56, 128)  0           block2_conv2[0][0]
# __________________________________________________________________________________________________
# block3_conv1 (Conv2D)           (None, 56, 56, 256)  295168      block2_pool[0][0]
# __________________________________________________________________________________________________
# block3_conv2 (Conv2D)           (None, 56, 56, 256)  590080      block3_conv1[0][0]
# __________________________________________________________________________________________________
# block3_conv3 (Conv2D)           (None, 56, 56, 256)  590080      block3_conv2[0][0]
# __________________________________________________________________________________________________
# block3_pool (MaxPooling2D)      (None, 28, 28, 256)  0           block3_conv3[0][0]
# __________________________________________________________________________________________________
# block4_conv1 (Conv2D)           (None, 28, 28, 512)  1180160     block3_pool[0][0]
# __________________________________________________________________________________________________
# block4_conv2 (Conv2D)           (None, 28, 28, 512)  2359808     block4_conv1[0][0]
# __________________________________________________________________________________________________
# block4_conv3 (Conv2D)           (None, 28, 28, 512)  2359808     block4_conv2[0][0]
# __________________________________________________________________________________________________
# block4_pool (MaxPooling2D)      (None, 14, 14, 512)  0           block4_conv3[0][0]
# __________________________________________________________________________________________________
# block5_conv1 (Conv2D)           (None, 14, 14, 512)  2359808     block4_pool[0][0]
# __________________________________________________________________________________________________
# block5_conv2 (Conv2D)           (None, 14, 14, 512)  2359808     block5_conv1[0][0]
# __________________________________________________________________________________________________
# block5_conv3 (Conv2D)           (None, 14, 14, 512)  2359808     block5_conv2[0][0]
# __________________________________________________________________________________________________
# block5_pool (MaxPooling2D)      (None, 7, 7, 512)    0           block5_conv3[0][0]
# __________________________________________________________________________________________________
# conv6 (Conv2D)                  (None, 7, 7, 4096)   102764544   block5_pool[0][0]
# __________________________________________________________________________________________________
# pool4_11 (Conv2D)               (None, 14, 14, 12)   6156        block4_pool[0][0]
# __________________________________________________________________________________________________
# conv7 (Conv2D)                  (None, 7, 7, 4096)   16781312    conv6[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 28, 28, 12)   576         pool4_11[0][0]
# __________________________________________________________________________________________________
# pool3_11 (Conv2D)               (None, 28, 28, 12)   3084        block3_pool[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 28, 28, 12)   786432      conv7[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 28, 28, 12)   0           conv2d_transpose_2[0][0]
#                                                                  pool3_11[0][0]
#                                                                  conv2d_transpose_1[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 224, 224, 12) 9216        add[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 224, 224, 12) 0           conv2d_transpose_3[0][0]
# ==================================================================================================
# Total params: 135,066,008
# Trainable params: 135,066,008
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from sklearn.utils import shuffle
train_rate = 0.85
index_train = np.random.choice(X.shape[0],int(X.shape[0]*train_rate),replace=False)
index_test  = list(set(range(X.shape[0])) - set(index_train))
                            
X, Y = shuffle(X,Y)
X_train, y_train = X[index_train],Y[index_train]
X_test, y_test = X[index_test],Y[index_test]
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (311, 224, 224, 3) (311, 224, 224, 12)
# (56, 224, 224, 3) (56, 224, 224, 12)

# %% [markdown]
# # **Training starts here**

# %%
from keras import optimizers


sgd = optimizers.SGD(lr=1E-2, decay=5**(-4), momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy',
              optimizer=sgd,
              metrics=['accuracy'])

hist1 = model.fit(X_train,y_train,
                  validation_data=(X_test,y_test),
                  batch_size=32,epochs=200,verbose=2)
# Out:
# Train on 311 samples, validate on 56 samples
# Epoch 1/200
#  - 15s - loss: 1.9777 - acc: 0.4393 - val_loss: 2.2355 - val_acc: 0.2739
# Epoch 2/200
#  - 12s - loss: 2.3703 - acc: 0.3410 - val_loss: 1.5922 - val_acc: 0.4826
# Epoch 3/200
#  - 12s - loss: 1.5223 - acc: 0.5506 - val_loss: 1.1746 - val_acc: 0.6265
# Epoch 4/200
#  - 12s - loss: 1.1032 - acc: 0.6581 - val_loss: 1.0360 - val_acc: 0.6707
# Epoch 5/200
#  - 12s - loss: 1.0130 - acc: 0.6805 - val_loss: 0.9824 - val_acc: 0.6908
# Epoch 6/200
#  - 12s - loss: 0.9665 - acc: 0.6926 - val_loss: 0.9469 - val_acc: 0.6987
# Epoch 7/200
#  - 12s - loss: 0.9290 - acc: 0.7097 - val_loss: 0.9109 - val_acc: 0.7147
# Epoch 8/200
#  - 12s - loss: 0.8938 - acc: 0.7205 - val_loss: 0.8820 - val_acc: 0.7245
# Epoch 9/200
#  - 12s - loss: 0.8954 - acc: 0.7192 - val_loss: 0.8629 - val_acc: 0.7355
# Epoch 10/200
#  - 12s - loss: 0.8438 - acc: 0.7392 - val_loss: 0.8292 - val_acc: 0.7474
# Epoch 11/200
#  - 12s - loss: 0.8672 - acc: 0.7328 - val_loss: 0.8137 - val_acc: 0.7520
# Epoch 12/200
#  - 12s - loss: 0.8150 - acc: 0.7503 - val_loss: 0.8246 - val_acc: 0.7519
# Epoch 13/200
#  - 12s - loss: 0.8281 - acc: 0.7445 - val_loss: 0.7933 - val_acc: 0.7610
# Epoch 14/200
#  - 12s - loss: 0.7780 - acc: 0.7663 - val_loss: 0.7928 - val_acc: 0.7621
# Epoch 15/200
#  - 12s - loss: 0.8110 - acc: 0.7525 - val_loss: 0.7759 - val_acc: 0.7743
# Epoch 16/200
#  - 12s - loss: 0.7560 - acc: 0.7764 - val_loss: 0.7555 - val_acc: 0.7781
# Epoch 17/200
#  - 12s - loss: 0.7498 - acc: 0.7783 - val_loss: 0.7383 - val_acc: 0.7825
# Epoch 18/200
#  - 12s - loss: 0.7339 - acc: 0.7832 - val_loss: 0.7847 - val_acc: 0.7599
# Epoch 19/200
#  - 12s - loss: 0.7730 - acc: 0.7663 - val_loss: 0.7502 - val_acc: 0.7808
# Epoch 20/200
#  - 12s - loss: 0.7165 - acc: 0.7900 - val_loss: 0.7351 - val_acc: 0.7823
# Epoch 21/200
#  - 12s - loss: 0.7092 - acc: 0.7916 - val_loss: 0.7091 - val_acc: 0.7924
# Epoch 22/200
#  - 12s - loss: 0.7209 - acc: 0.7862 - val_loss: 0.6937 - val_acc: 0.7984
# Epoch 23/200
#  - 12s - loss: 0.7003 - acc: 0.7947 - val_loss: 0.6843 - val_acc: 0.8049
# Epoch 24/200
#  - 12s - loss: 0.6884 - acc: 0.7978 - val_loss: 0.6871 - val_acc: 0.8039
# Epoch 25/200
#  - 12s - loss: 0.7199 - acc: 0.7854 - val_loss: 0.6843 - val_acc: 0.8025
# Epoch 26/200
#  - 12s - loss: 0.6746 - acc: 0.8037 - val_loss: 0.7081 - val_acc: 0.7929
# Epoch 27/200
#  - 12s - loss: 0.6822 - acc: 0.7998 - val_loss: 0.6672 - val_acc: 0.8098
# Epoch 28/200
#  - 12s - loss: 0.6854 - acc: 0.7986 - val_loss: 0.6952 - val_acc: 0.7980
# Epoch 29/200
#  - 12s - loss: 0.6665 - acc: 0.8053 - val_loss: 0.6543 - val_acc: 0.8123
# Epoch 30/200
#  - 12s - loss: 0.6484 - acc: 0.8119 - val_loss: 0.6616 - val_acc: 0.8083
# Epoch 31/200
#  - 12s - loss: 0.6561 - acc: 0.8070 - val_loss: 0.6592 - val_acc: 0.8122
# Epoch 32/200
#  - 12s - loss: 0.6550 - acc: 0.8098 - val_loss: 0.6447 - val_acc: 0.8176
# Epoch 33/200
#  - 12s - loss: 0.6327 - acc: 0.8166 - val_loss: 0.6495 - val_acc: 0.8139
# Epoch 34/200
#  - 12s - loss: 0.6428 - acc: 0.8118 - val_loss: 0.6299 - val_acc: 0.8212
# Epoch 35/200
#  - 12s - loss: 0.6254 - acc: 0.8187 - val_loss: 0.6316 - val_acc: 0.8156
# Epoch 36/200
#  - 12s - loss: 0.6325 - acc: 0.8158 - val_loss: 0.6694 - val_acc: 0.8067
# Epoch 37/200
#  - 12s - loss: 0.6239 - acc: 0.8187 - val_loss: 0.6478 - val_acc: 0.8128
# Epoch 38/200
#  - 12s - loss: 0.6171 - acc: 0.8212 - val_loss: 0.6092 - val_acc: 0.8253
# Epoch 39/200
#  - 12s - loss: 0.6327 - acc: 0.8154 - val_loss: 0.6218 - val_acc: 0.8263
# Epoch 40/200
#  - 12s - loss: 0.6023 - acc: 0.8260 - val_loss: 0.5977 - val_acc: 0.8285
# Epoch 41/200
#  - 12s - loss: 0.6237 - acc: 0.8171 - val_loss: 0.6107 - val_acc: 0.8266
# Epoch 42/200
#  - 12s - loss: 0.5976 - acc: 0.8276 - val_loss: 0.5964 - val_acc: 0.8277
# Epoch 43/200
#  - 12s - loss: 0.5915 - acc: 0.8287 - val_loss: 0.5941 - val_acc: 0.8280
# Epoch 44/200
#  - 12s - loss: 0.5873 - acc: 0.8304 - val_loss: 0.5940 - val_acc: 0.8317
# Epoch 45/200
#  - 12s - loss: 0.6128 - acc: 0.8210 - val_loss: 0.5849 - val_acc: 0.8343
# Epoch 46/200
#  - 12s - loss: 0.5803 - acc: 0.8322 - val_loss: 0.5819 - val_acc: 0.8353
# Epoch 47/200
#  - 12s - loss: 0.5782 - acc: 0.8336 - val_loss: 0.6048 - val_acc: 0.8299
# Epoch 48/200
#  - 12s - loss: 0.5793 - acc: 0.8327 - val_loss: 0.5993 - val_acc: 0.8262
# Epoch 49/200
#  - 12s - loss: 0.5761 - acc: 0.8334 - val_loss: 0.5816 - val_acc: 0.8321
# Epoch 50/200
#  - 12s - loss: 0.5697 - acc: 0.8357 - val_loss: 0.5683 - val_acc: 0.8382
# Epoch 51/200
#  - 12s - loss: 0.5607 - acc: 0.8387 - val_loss: 0.5744 - val_acc: 0.8385
# Epoch 52/200
#  - 12s - loss: 0.5616 - acc: 0.8384 - val_loss: 0.5659 - val_acc: 0.8395
# Epoch 53/200
#  - 12s - loss: 0.5728 - acc: 0.8341 - val_loss: 0.6294 - val_acc: 0.8174
# Epoch 54/200
#  - 12s - loss: 0.5636 - acc: 0.8370 - val_loss: 0.5627 - val_acc: 0.8386
# Epoch 55/200
#  - 12s - loss: 0.5534 - acc: 0.8404 - val_loss: 0.5674 - val_acc: 0.8411
# Epoch 56/200
#  - 12s - loss: 0.5562 - acc: 0.8395 - val_loss: 0.5637 - val_acc: 0.8386
# Epoch 57/200
#  - 12s - loss: 0.5512 - acc: 0.8408 - val_loss: 0.5531 - val_acc: 0.8453
# Epoch 58/200
#  - 12s - loss: 0.5425 - acc: 0.8445 - val_loss: 0.5540 - val_acc: 0.8448
# Epoch 59/200
#  - 12s - loss: 0.5436 - acc: 0.8440 - val_loss: 0.5472 - val_acc: 0.8471
# Epoch 60/200
#  - 12s - loss: 0.5425 - acc: 0.8445 - val_loss: 0.5666 - val_acc: 0.8341
# Epoch 61/200
#  - 12s - loss: 0.5458 - acc: 0.8425 - val_loss: 0.5543 - val_acc: 0.8414
# Epoch 62/200
#  - 12s - loss: 0.5342 - acc: 0.8462 - val_loss: 0.5554 - val_acc: 0.8416
# Epoch 63/200
#  - 12s - loss: 0.5300 - acc: 0.8484 - val_loss: 0.5554 - val_acc: 0.8401
# Epoch 64/200
#  - 12s - loss: 0.5388 - acc: 0.8444 - val_loss: 0.5406 - val_acc: 0.8466
# Epoch 65/200
#  - 12s - loss: 0.5278 - acc: 0.8482 - val_loss: 0.5366 - val_acc: 0.8499
# Epoch 66/200
#  - 12s - loss: 0.5209 - acc: 0.8510 - val_loss: 0.5345 - val_acc: 0.8505
# Epoch 67/200
#  - 12s - loss: 0.5205 - acc: 0.8511 - val_loss: 0.5550 - val_acc: 0.8399
# Epoch 68/200
#  - 12s - loss: 0.5441 - acc: 0.8416 - val_loss: 0.5405 - val_acc: 0.8494
# Epoch 69/200
#  - 12s - loss: 0.5169 - acc: 0.8517 - val_loss: 0.5300 - val_acc: 0.8510
# Epoch 70/200
#  - 12s - loss: 0.5149 - acc: 0.8525 - val_loss: 0.5465 - val_acc: 0.8454
# Epoch 71/200
#  - 12s - loss: 0.5245 - acc: 0.8488 - val_loss: 0.5314 - val_acc: 0.8512
# Epoch 72/200
#  - 12s - loss: 0.5122 - acc: 0.8532 - val_loss: 0.5270 - val_acc: 0.8519
# Epoch 73/200
#  - 12s - loss: 0.5068 - acc: 0.8550 - val_loss: 0.5331 - val_acc: 0.8494
# Epoch 74/200
#  - 12s - loss: 0.5128 - acc: 0.8529 - val_loss: 0.5326 - val_acc: 0.8482
# Epoch 75/200
#  - 12s - loss: 0.5101 - acc: 0.8531 - val_loss: 0.5218 - val_acc: 0.8543
# Epoch 76/200
#  - 12s - loss: 0.5017 - acc: 0.8567 - val_loss: 0.5229 - val_acc: 0.8528
# Epoch 77/200
#  - 12s - loss: 0.5266 - acc: 0.8473 - val_loss: 0.5716 - val_acc: 0.8328
# Epoch 78/200
#  - 12s - loss: 0.5139 - acc: 0.8523 - val_loss: 0.5353 - val_acc: 0.8467
# Epoch 79/200
#  - 12s - loss: 0.5051 - acc: 0.8547 - val_loss: 0.5393 - val_acc: 0.8443
# Epoch 80/200
#  - 12s - loss: 0.5062 - acc: 0.8547 - val_loss: 0.5213 - val_acc: 0.8530
# Epoch 81/200
#  - 12s - loss: 0.4949 - acc: 0.8585 - val_loss: 0.5151 - val_acc: 0.8556
# Epoch 82/200
#  - 12s - loss: 0.4985 - acc: 0.8567 - val_loss: 0.5150 - val_acc: 0.8559
# Epoch 83/200
#  - 12s - loss: 0.5114 - acc: 0.8522 - val_loss: 0.5173 - val_acc: 0.8541
# Epoch 84/200
#  - 12s - loss: 0.4933 - acc: 0.8581 - val_loss: 0.5164 - val_acc: 0.8543
# Epoch 85/200
#  - 12s - loss: 0.4910 - acc: 0.8593 - val_loss: 0.5120 - val_acc: 0.8559
# Epoch 86/200
#  - 12s - loss: 0.4877 - acc: 0.8602 - val_loss: 0.5155 - val_acc: 0.8553
# Epoch 87/200
#  - 12s - loss: 0.4833 - acc: 0.8620 - val_loss: 0.5114 - val_acc: 0.8559
# Epoch 88/200
#  - 12s - loss: 0.4807 - acc: 0.8627 - val_loss: 0.5168 - val_acc: 0.8540
# Epoch 89/200
#  - 12s - loss: 0.4860 - acc: 0.8604 - val_loss: 0.5230 - val_acc: 0.8531
# Epoch 90/200
#  - 12s - loss: 0.4884 - acc: 0.8592 - val_loss: 0.5057 - val_acc: 0.8581
# Epoch 91/200
#  - 12s - loss: 0.4770 - acc: 0.8637 - val_loss: 0.5067 - val_acc: 0.8574
# Epoch 92/200
#  - 12s - loss: 0.4815 - acc: 0.8621 - val_loss: 0.5190 - val_acc: 0.8530
# Epoch 93/200
#  - 12s - loss: 0.4873 - acc: 0.8605 - val_loss: 0.5132 - val_acc: 0.8537
# Epoch 94/200
#  - 12s - loss: 0.4809 - acc: 0.8620 - val_loss: 0.5204 - val_acc: 0.8527
# Epoch 95/200
#  - 12s - loss: 0.4748 - acc: 0.8640 - val_loss: 0.5192 - val_acc: 0.8545
# Epoch 96/200
#  - 12s - loss: 0.4837 - acc: 0.8604 - val_loss: 0.5058 - val_acc: 0.8581
# Epoch 97/200
#  - 12s - loss: 0.4881 - acc: 0.8594 - val_loss: 0.5053 - val_acc: 0.8584
# Epoch 98/200
#  - 12s - loss: 0.4695 - acc: 0.8659 - val_loss: 0.5006 - val_acc: 0.8595
# Epoch 99/200
#  - 12s - loss: 0.4709 - acc: 0.8658 - val_loss: 0.5143 - val_acc: 0.8561
# Epoch 100/200
#  - 12s - loss: 0.4661 - acc: 0.8673 - val_loss: 0.5057 - val_acc: 0.8572
# Epoch 101/200
#  - 12s - loss: 0.4758 - acc: 0.8628 - val_loss: 0.5023 - val_acc: 0.8582
# Epoch 102/200
#  - 12s - loss: 0.4760 - acc: 0.8636 - val_loss: 0.5025 - val_acc: 0.8591
# Epoch 103/200
#  - 12s - loss: 0.4631 - acc: 0.8680 - val_loss: 0.5049 - val_acc: 0.8578
# Epoch 104/200
#  - 12s - loss: 0.4731 - acc: 0.8640 - val_loss: 0.5161 - val_acc: 0.8554
# Epoch 105/200
#  - 12s - loss: 0.4666 - acc: 0.8666 - val_loss: 0.5034 - val_acc: 0.8579
# Epoch 106/200
#  - 12s - loss: 0.4592 - acc: 0.8688 - val_loss: 0.4993 - val_acc: 0.8601
# Epoch 107/200
#  - 12s - loss: 0.4579 - acc: 0.8694 - val_loss: 0.5115 - val_acc: 0.8557
# Epoch 108/200
#  - 12s - loss: 0.4598 - acc: 0.8687 - val_loss: 0.4968 - val_acc: 0.8607
# Epoch 109/200
#  - 12s - loss: 0.4557 - acc: 0.8699 - val_loss: 0.4980 - val_acc: 0.8606
# Epoch 110/200
#  - 12s - loss: 0.4524 - acc: 0.8711 - val_loss: 0.5345 - val_acc: 0.8473
# Epoch 111/200
#  - 12s - loss: 0.4803 - acc: 0.8611 - val_loss: 0.4976 - val_acc: 0.8607
# Epoch 112/200
#  - 12s - loss: 0.4572 - acc: 0.8692 - val_loss: 0.5391 - val_acc: 0.8462
# Epoch 113/200
#  - 12s - loss: 0.4689 - acc: 0.8654 - val_loss: 0.4961 - val_acc: 0.8607
# Epoch 114/200
#  - 12s - loss: 0.4518 - acc: 0.8714 - val_loss: 0.5030 - val_acc: 0.8580
# Epoch 115/200
#  - 12s - loss: 0.4519 - acc: 0.8714 - val_loss: 0.5008 - val_acc: 0.8592
# Epoch 116/200
#  - 12s - loss: 0.4478 - acc: 0.8727 - val_loss: 0.4968 - val_acc: 0.8611
# Epoch 117/200
#  - 12s - loss: 0.4483 - acc: 0.8723 - val_loss: 0.5128 - val_acc: 0.8550
# Epoch 118/200
#  - 12s - loss: 0.4474 - acc: 0.8723 - val_loss: 0.4950 - val_acc: 0.8617
# Epoch 119/200
#  - 12s - loss: 0.4460 - acc: 0.8731 - val_loss: 0.4928 - val_acc: 0.8615
# Epoch 120/200
#  - 12s - loss: 0.4427 - acc: 0.8740 - val_loss: 0.5204 - val_acc: 0.8523
# Epoch 121/200
#  - 12s - loss: 0.4556 - acc: 0.8688 - val_loss: 0.4957 - val_acc: 0.8601
# Epoch 122/200
#  - 12s - loss: 0.4435 - acc: 0.8736 - val_loss: 0.4916 - val_acc: 0.8623
# Epoch 123/200
#  - 12s - loss: 0.4418 - acc: 0.8743 - val_loss: 0.4965 - val_acc: 0.8597
# Epoch 124/200
#  - 12s - loss: 0.4420 - acc: 0.8743 - val_loss: 0.5043 - val_acc: 0.8581
# Epoch 125/200
#  - 12s - loss: 0.4447 - acc: 0.8731 - val_loss: 0.4946 - val_acc: 0.8621
# Epoch 126/200
#  - 12s - loss: 0.4445 - acc: 0.8734 - val_loss: 0.4943 - val_acc: 0.8613
# Epoch 127/200
#  - 12s - loss: 0.4377 - acc: 0.8752 - val_loss: 0.4863 - val_acc: 0.8638
# Epoch 128/200
#  - 12s - loss: 0.4430 - acc: 0.8739 - val_loss: 0.4893 - val_acc: 0.8626
# Epoch 129/200
#  - 12s - loss: 0.4316 - acc: 0.8775 - val_loss: 0.4866 - val_acc: 0.8636
# Epoch 130/200
#  - 12s - loss: 0.4334 - acc: 0.8767 - val_loss: 0.4976 - val_acc: 0.8596
# Epoch 131/200
#  - 12s - loss: 0.4468 - acc: 0.8721 - val_loss: 0.4938 - val_acc: 0.8624
# Epoch 132/200
#  - 12s - loss: 0.4305 - acc: 0.8782 - val_loss: 0.5052 - val_acc: 0.8575
# Epoch 133/200
#  - 12s - loss: 0.4377 - acc: 0.8748 - val_loss: 0.4977 - val_acc: 0.8590
# Epoch 134/200
#  - 12s - loss: 0.4288 - acc: 0.8784 - val_loss: 0.4854 - val_acc: 0.8636
# Epoch 135/200
#  - 12s - loss: 0.4293 - acc: 0.8779 - val_loss: 0.5060 - val_acc: 0.8579
# Epoch 136/200
#  - 12s - loss: 0.4312 - acc: 0.8777 - val_loss: 0.5098 - val_acc: 0.8565
# Epoch 137/200
#  - 12s - loss: 0.4404 - acc: 0.8747 - val_loss: 0.4869 - val_acc: 0.8642
# Epoch 138/200
#  - 12s - loss: 0.4330 - acc: 0.8767 - val_loss: 0.4900 - val_acc: 0.8625
# Epoch 139/200
#  - 12s - loss: 0.4299 - acc: 0.8776 - val_loss: 0.4831 - val_acc: 0.8645
# Epoch 140/200
#  - 12s - loss: 0.4210 - acc: 0.8810 - val_loss: 0.4870 - val_acc: 0.8638
# Epoch 141/200
#  - 12s - loss: 0.4223 - acc: 0.8804 - val_loss: 0.4892 - val_acc: 0.8628
# Epoch 142/200
#  - 12s - loss: 0.4253 - acc: 0.8792 - val_loss: 0.4863 - val_acc: 0.8636
# Epoch 143/200
#  - 12s - loss: 0.4268 - acc: 0.8785 - val_loss: 0.4994 - val_acc: 0.8586
# Epoch 144/200
#  - 12s - loss: 0.4223 - acc: 0.8804 - val_loss: 0.4967 - val_acc: 0.8620
# Epoch 145/200
#  - 12s - loss: 0.4292 - acc: 0.8777 - val_loss: 0.4878 - val_acc: 0.8626
# Epoch 146/200
#  - 12s - loss: 0.4170 - acc: 0.8818 - val_loss: 0.4866 - val_acc: 0.8636
# Epoch 147/200
#  - 12s - loss: 0.4577 - acc: 0.8688 - val_loss: 0.4827 - val_acc: 0.8640
# Epoch 148/200
#  - 12s - loss: 0.4204 - acc: 0.8809 - val_loss: 0.4801 - val_acc: 0.8653
# Epoch 149/200
#  - 12s - loss: 0.4157 - acc: 0.8825 - val_loss: 0.4891 - val_acc: 0.8619
# Epoch 150/200
#  - 12s - loss: 0.4172 - acc: 0.8818 - val_loss: 0.4806 - val_acc: 0.8657
# Epoch 151/200
#  - 12s - loss: 0.4123 - acc: 0.8836 - val_loss: 0.4781 - val_acc: 0.8657
# Epoch 152/200
#  - 12s - loss: 0.4145 - acc: 0.8831 - val_loss: 0.4896 - val_acc: 0.8637
# Epoch 153/200
#  - 12s - loss: 0.4207 - acc: 0.8801 - val_loss: 0.4789 - val_acc: 0.8658
# Epoch 154/200
#  - 12s - loss: 0.4141 - acc: 0.8826 - val_loss: 0.4788 - val_acc: 0.8653
# Epoch 155/200
#  - 12s - loss: 0.4105 - acc: 0.8842 - val_loss: 0.4935 - val_acc: 0.8620
# Epoch 156/200
#  - 12s - loss: 0.4137 - acc: 0.8830 - val_loss: 0.4868 - val_acc: 0.8630
# Epoch 157/200
#  - 12s - loss: 0.4143 - acc: 0.8825 - val_loss: 0.4822 - val_acc: 0.8649
# Epoch 158/200
#  - 12s - loss: 0.4142 - acc: 0.8830 - val_loss: 0.4843 - val_acc: 0.8640
# Epoch 159/200
#  - 12s - loss: 0.4080 - acc: 0.8848 - val_loss: 0.4750 - val_acc: 0.8672
# Epoch 160/200
#  - 12s - loss: 0.4109 - acc: 0.8838 - val_loss: 0.4888 - val_acc: 0.8621
# Epoch 161/200
#  - 12s - loss: 0.4128 - acc: 0.8832 - val_loss: 0.4794 - val_acc: 0.8661
# Epoch 162/200
#  - 12s - loss: 0.4062 - acc: 0.8854 - val_loss: 0.4843 - val_acc: 0.8642
# Epoch 163/200
#  - 12s - loss: 0.4066 - acc: 0.8852 - val_loss: 0.4852 - val_acc: 0.8641
# Epoch 164/200
#  - 12s - loss: 0.4035 - acc: 0.8863 - val_loss: 0.4790 - val_acc: 0.8665
# Epoch 165/200
#  - 12s - loss: 0.4131 - acc: 0.8831 - val_loss: 0.4999 - val_acc: 0.8576
# Epoch 166/200
#  - 12s - loss: 0.4058 - acc: 0.8851 - val_loss: 0.4776 - val_acc: 0.8662
# Epoch 167/200
#  - 12s - loss: 0.4015 - acc: 0.8870 - val_loss: 0.4880 - val_acc: 0.8624
# Epoch 168/200
#  - 12s - loss: 0.4107 - acc: 0.8834 - val_loss: 0.4746 - val_acc: 0.8672
# Epoch 169/200
#  - 12s - loss: 0.4007 - acc: 0.8872 - val_loss: 0.5013 - val_acc: 0.8598
# Epoch 170/200
#  - 12s - loss: 0.4063 - acc: 0.8851 - val_loss: 0.4971 - val_acc: 0.8582
# Epoch 171/200
#  - 12s - loss: 0.4013 - acc: 0.8867 - val_loss: 0.4783 - val_acc: 0.8654
# Epoch 172/200
#  - 12s - loss: 0.3988 - acc: 0.8880 - val_loss: 0.4893 - val_acc: 0.8629
# Epoch 173/200
#  - 12s - loss: 0.4054 - acc: 0.8856 - val_loss: 0.4798 - val_acc: 0.8649
# Epoch 174/200
#  - 12s - loss: 0.4045 - acc: 0.8856 - val_loss: 0.4844 - val_acc: 0.8644
# Epoch 175/200
#  - 12s - loss: 0.3988 - acc: 0.8874 - val_loss: 0.4940 - val_acc: 0.8607
# Epoch 176/200
#  - 12s - loss: 0.3952 - acc: 0.8885 - val_loss: 0.4782 - val_acc: 0.8670
# Epoch 177/200
#  - 12s - loss: 0.4039 - acc: 0.8852 - val_loss: 0.4832 - val_acc: 0.8637
# Epoch 178/200
#  - 12s - loss: 0.3945 - acc: 0.8890 - val_loss: 0.4734 - val_acc: 0.8669
# Epoch 179/200
#  - 12s - loss: 0.4074 - acc: 0.8850 - val_loss: 0.4812 - val_acc: 0.8647
# Epoch 180/200
#  - 12s - loss: 0.3933 - acc: 0.8895 - val_loss: 0.4897 - val_acc: 0.8624
# Epoch 181/200
#  - 12s - loss: 0.3946 - acc: 0.8892 - val_loss: 0.4853 - val_acc: 0.8627
# Epoch 182/200
#  - 12s - loss: 0.3911 - acc: 0.8900 - val_loss: 0.4721 - val_acc: 0.8682
# Epoch 183/200
#  - 12s - loss: 0.3893 - acc: 0.8909 - val_loss: 0.4895 - val_acc: 0.8623
# Epoch 184/200
#  - 12s - loss: 0.4087 - acc: 0.8841 - val_loss: 0.4726 - val_acc: 0.8667
# Epoch 185/200
#  - 12s - loss: 0.3882 - acc: 0.8909 - val_loss: 0.4762 - val_acc: 0.8667
# Epoch 186/200
#  - 12s - loss: 0.3933 - acc: 0.8891 - val_loss: 0.4753 - val_acc: 0.8671
# Epoch 187/200
#  - 12s - loss: 0.3868 - acc: 0.8916 - val_loss: 0.4891 - val_acc: 0.8624
# Epoch 188/200
#  - 12s - loss: 0.3892 - acc: 0.8904 - val_loss: 0.4845 - val_acc: 0.8654
# Epoch 189/200
#  - 12s - loss: 0.3971 - acc: 0.8876 - val_loss: 0.4774 - val_acc: 0.8661
# Epoch 190/200
#  - 12s - loss: 0.3871 - acc: 0.8912 - val_loss: 0.4764 - val_acc: 0.8659
# Epoch 191/200
#  - 12s - loss: 0.3923 - acc: 0.8892 - val_loss: 0.4732 - val_acc: 0.8680
# Epoch 192/200
#  - 12s - loss: 0.3832 - acc: 0.8925 - val_loss: 0.4767 - val_acc: 0.8665
# Epoch 193/200
#  - 12s - loss: 0.3843 - acc: 0.8924 - val_loss: 0.4831 - val_acc: 0.8642
# Epoch 194/200
#  - 12s - loss: 0.3841 - acc: 0.8924 - val_loss: 0.4787 - val_acc: 0.8662
# Epoch 195/200
#  - 12s - loss: 0.3855 - acc: 0.8916 - val_loss: 0.4806 - val_acc: 0.8655
# Epoch 196/200
#  - 12s - loss: 0.3869 - acc: 0.8916 - val_loss: 0.4805 - val_acc: 0.8651
# Epoch 197/200
#  - 12s - loss: 0.3839 - acc: 0.8922 - val_loss: 0.4854 - val_acc: 0.8630
# Epoch 198/200
#  - 12s - loss: 0.3913 - acc: 0.8892 - val_loss: 0.4736 - val_acc: 0.8670
# Epoch 199/200
#  - 12s - loss: 0.3784 - acc: 0.8943 - val_loss: 0.4790 - val_acc: 0.8658
# Epoch 200/200
#  - 12s - loss: 0.3853 - acc: 0.8915 - val_loss: 0.4775 - val_acc: 0.8661

# %%
history_file = '/content/gdrive/My Drive/Colab Notebooks/semanticseg_vgg_v2.csv'
pd.DataFrame(hist1.history).to_csv(history_file, mode='w', header=True)

# %% [markdown]
# ## **Plot the change in loss over epochs**

# %%
for key in ['loss', 'val_loss']:
    plt.plot(hist1.history[key],label=key)
plt.legend()
plt.show()

# %% [markdown]
# **Calculate intersection over union for each segmentation class**

# %%
y_pred = model.predict(X_test)
y_predi = np.argmax(y_pred, axis=3)
y_testi = np.argmax(y_test, axis=3)
print(y_testi.shape,y_predi.shape)


def IoU(Yi,y_predi):
    ## mean Intersection over Union
    ## Mean IoU = TP/(FN + TP + FP)

    IoUs = []
    Nclass = int(np.max(Yi)) + 1
    for c in range(Nclass):
        TP = np.sum( (Yi == c)&(y_predi==c) )
        FP = np.sum( (Yi != c)&(y_predi==c) )
        FN = np.sum( (Yi == c)&(y_predi != c)) 
        IoU = TP/float(TP + FP + FN)
        print("class {:02.0f}: #TP={:6.0f}, #FP={:6.0f}, #FN={:5.0f}, IoU={:4.3f}".format(c,TP,FP,FN,IoU))
        IoUs.append(IoU)
    mIoU = np.mean(IoUs)
    print("_________________")
    print("Mean IoU: {:4.3f}".format(mIoU))
    
IoU(y_testi,y_predi)
# Out:
# (56, 224, 224) (56, 224, 224)
# class 00: #TP=383580, #FP= 50358, #FN=19471, IoU=0.846
# class 01: #TP=617393, #FP= 93612, #FN=56178, IoU=0.805
# class 02: #TP=    28, #FP=   112, #FN=35211, IoU=0.001
# class 03: #TP=897462, #FP= 47019, #FN=27926, IoU=0.923
# class 04: #TP=101570, #FP= 24664, #FN=45785, IoU=0.590
# class 05: #TP=240359, #FP= 81412, #FN=31797, IoU=0.680
# class 06: #TP=  1382, #FP=  2140, #FN=40548, IoU=0.031
# class 07: #TP= 12690, #FP=  8782, #FN=23211, IoU=0.284
# class 08: #TP=138605, #FP= 35036, #FN=25883, IoU=0.695
# class 09: #TP=  1504, #FP=  3844, #FN=23404, IoU=0.052
# class 10: #TP=   314, #FP=   650, #FN= 9004, IoU=0.032
# class 11: #TP= 38832, #FP= 28508, #FN=37719, IoU=0.370
# _________________
# Mean IoU: 0.442

# %% [markdown]
# # **Visualize the model performance**

# %%
shape = (224,224)
n_classes= 10

for i in range(10):
    img_is  = (X_test[i] + 1)*(255.0/2)
    seg = y_predi[i]
    segtest = y_testi[i]

    fig = plt.figure(figsize=(10,30))    
    ax = fig.add_subplot(1,3,1)
    ax.imshow(img_is/255.0)
    ax.set_title("original")
    
    ax = fig.add_subplot(1,3,2)
    ax.imshow(give_color_to_seg_img(seg,n_classes))
    ax.set_title("predicted class")
    
    ax = fig.add_subplot(1,3,3)
    ax.imshow(give_color_to_seg_img(segtest,n_classes))
    ax.set_title("true class")
    plt.show()
